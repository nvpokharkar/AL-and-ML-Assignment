# %%
# loading initail libraries
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
#reading a csv file
df=pd.read_csv("C:/Users/admin/OneDrive/Desktop/Third semester/Artificial Intelligance and Machine Learning/archive (2)/New data file.csv")

# %%
#first 20 lines
df.head(20)
# Out:
#     customer_id  shipment_location_lat  shipment_location_long  total_amount
# 0          5868              -8.227893              111.969107        199832
# 1          4774               3.013470              107.802514        155526
# 2          4774              -2.579428              115.743885        550696
# 3          4774              -3.602334              120.363823        271012
# 4          4774              -3.602334              120.363823        198753
# 5          4774              -3.602334              120.363823        181865
# 6          4774              -7.712608              110.502877        306599
# 7          4774               3.293114               98.857043        153913
# 8          4774              -6.126016              106.779552        370757
# 9          4774              -0.992004              114.438739       1295740
# 10         4774              -5.201649              105.760460       1895458
# ...

# %%
# Check for missing values
missing_values = df.isnull()
print(missing_values)
# Out:
#         customer_id  shipment_location_lat  shipment_location_long  \
# 0             False                  False                   False
# 1             False                  False                   False
# 2             False                  False                   False
# 3             False                  False                   False
# 4             False                  False                   False
# ...             ...                    ...                     ...
# 852579        False                  False                   False
# 852580        False                  False                   False
# 852581        False                  False                   False
# 852582        False                  False                   False
# 852583        False                  False                   False
#
#         total_amount
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# ...

# %% [markdown]
# I guess no missing value in the data set.

# %% [markdown]
# Question 4) I need you help in class because I didn't understand the data set, so could you please help me about analysis, right now Whatever I understand I did inthis exercise.
# hopefull understand and help me.
